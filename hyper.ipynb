# %%
import os

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 62.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 59.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 62.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import datetime
import shutil
from pathlib import Path
from collections import Counter

import yaml
import numpy as np
import pandas as pd
from ultralytics import YOLO
from sklearn.model_selection import KFold

# %%
import cv2

# %%
import torch

# %%
model = YOLO('yolov8s-seg.pt')

model.tune(resume = True)
# Out:
# ...
# 100%|██████████| 22.8M/22.8M [00:00<00:00, 156MB/s]
# Tuner: Initialized Tuner instance with 'tune_dir=runs/segment/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/10 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8b06c520ed29> in <cell line: 3>()
#       1 model = YOLO('yolov8s-seg.pt')
#       2
# ----> 3 model.tune(resume = True)
#
# ...

# %%
model = YOLO('yolov8s-seg.pt')

model.tune(data='/content/gdrive/My Drive/ES100root/2024-03-18_5-Fold_Cross-val-345789/split_3/split_3_dataset.yaml', epochs=10, iterations=10, optimizer='SGD', plots=True, save=False, val=False)
# Out:
# ...
# 100%|██████████| 22.8M/22.8M [00:00<00:00, 294MB/s]
# Tuner: Initialized Tuner instance with 'tune_dir=runs/segment/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/10 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# Saved runs/segment/tune/tune_scatter_plots.png
# Saved runs/segment/tune/tune_fitness.png
#
# Tuner: 1/10 iterations complete ✅ (1239.65s)
# Tuner: Results saved to runs/segment/tune
# Tuner: Best fitness=1.4818 observed at iteration 1
# ...

# %%
models = YOLO('yolov8m-seg.pt')

models.tune(data='/content/gdrive/My Drive/ES100root/2024-03-14_5-Fold_Cross-val_134579/split_5/split_5_dataset.yaml', epochs=10, iterations=10, optimizer='AdamW', plots=True, save=False, val=False)
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/segment/tune8'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/10 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# WARNING ❌️ training failure for hyperparameter tuning iteration 1
# ...

# %%
model = YOLO('/content/gdrive/MyDrive/ES100root/runs/kfold_demo_345789_small/train6/weights/best.pt')

source = '/content/gdrive/MyDrive/ES100fullvideos/CDW_4.6.23_RUL_PA1.mp4'

# Run inference on the source
results = model(source, save=True, save_crop=True, project="/content/gdrive/My Drive/ES100fullvideos", name="exp3")  # generator of Results objects
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (frame 3203/9000) /content/gdrive/MyDrive/ES100fullvideos/CDW_4.6.23_RUL_PA1.mp4: 384x640 1 posterior ascending, 8.6ms
# video 1/1 (frame 3204/9000) /content/gdrive/MyDrive/ES100fullvideos/CDW_4.6.23_RUL_PA1.mp4: 384x640 1 posterior ascending, 9.3ms
# video 1/1 (frame 3205/9000) /content/gdrive/MyDrive/ES100fullvideos/CDW_4.6.23_RUL_PA1.mp4: 384x640 1 posterior ascending, 9.0ms
# video 1/1 (frame 3206/9000) /content/gdrive/MyDrive/ES100fullvideos/CDW_4.6.23_RUL_PA1.mp4: 384x640 1 posterior ascending, 9.7ms
# video 1/1 (frame 3207/9000) /content/gdrive/MyDrive/ES100fullvideos/CDW_4.6.23_RUL_PA1.mp4: 384x640 1 posterior ascending, 11.7ms
# video 1/1 (frame 3208/9000) /content/gdrive/MyDrive/ES100fullvideos/CDW_4.6.23_RUL_PA1.mp4: 384x640 1 posterior ascending, 9.2ms
# video 1/1 (frame 3209/9000) /content/gdrive/MyDrive/ES100fullvideos/CDW_4.6.23_RUL_PA1.mp4: 384x640 1 posterior ascending, 10.6ms
# ...
